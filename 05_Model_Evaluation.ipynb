# %%
import pandas as pd

classification_results = pd.DataFrame({
    "Model": [
        "MobileNetV2",
        "VGG16",
        "ResNet50",
        "EfficientNetB0"
    ],
    "Validation Accuracy": [
        0.4027,
        0.1573,
        0.0880,
        0.0400
    ]
})

classification_results
# Out:
#             Model  Validation Accuracy
# 0     MobileNetV2               0.4027
# 1           VGG16               0.1573
# 2        ResNet50               0.0880
# 3  EfficientNetB0               0.0400

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(
    classification_results["Model"],
    classification_results["Validation Accuracy"]
)

plt.title("Classification Model Comparison")
plt.ylabel("Validation Accuracy")

plt.show()

# %%
yolo_results = pd.DataFrame({
    "Metric": [
        "Precision",
        "Recall",
        "mAP50",
        "mAP50-95"
    ],
    "Value": [
        0.453,
        0.429,
        0.385,
        0.162
    ]
})

yolo_results
# Out:
#       Metric  Value
# 0  Precision  0.453
# 1     Recall  0.429
# 2      mAP50  0.385
# 3   mAP50-95  0.162

# %%
plt.figure(figsize=(8,5))

plt.bar(
    yolo_results["Metric"],
    yolo_results["Value"]
)

plt.title("YOLOv8 Performance Metrics")

plt.show()
